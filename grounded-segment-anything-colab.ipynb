# %% [markdown]
# <a href="https://colab.research.google.com/github/KJ-Falloutlast/CoLab_Project/blob/main/grounded-segment-anything-colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !pip install -q torch==2.0.0+cu118 torchvision==0.15.1+cu118 torchaudio==2.0.1+cu118 torchtext==0.15.1 torchdata==0.6.0 --extra-index-url https://download.pytorch.org/whl/cu118 -U
# !pip install -q xformers==0.0.18 triton==2.0.0 -U

# !apt-get -y install -qq aria2
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/camenduru/ovseg/resolve/main/sam_vit_h_4b8939.pth -d /content -o sam_vit_h_4b8939.pth

# !git clone -b dev https://github.com/camenduru/Grounded-Segment-Anything
# %cd /content/Grounded-Segment-Anything
# !pip install -q -r requirements.txt
# %cd /content/Grounded-Segment-Anything/GroundingDINO
# !pip install -q .
# %cd /content/Grounded-Segment-Anything/segment_anything
# !pip install -q .

import os
import shlex
import subprocess
from pathlib import Path
from typing import Union

id_rsa_file = "/content/Grounded-Segment-Anything/id_rsa"
id_rsa_pub_file = "/content/Grounded-Segment-Anything/id_rsa.pub"
if os.path.exists(id_rsa_file):
    os.remove(id_rsa_file)
if os.path.exists(id_rsa_pub_file):
    os.remove(id_rsa_pub_file)

def gen_key(path: Union[str, Path]) -> None:
    path = Path(path)
    arg_string = f'ssh-keygen -t rsa -b 4096 -N "" -q -f {path.as_posix()}'
    args = shlex.split(arg_string)
    subprocess.run(args, check=True)
    path.chmod(0o600)

ssh_name = "id_rsa"
ssh_path = Path(os.path.dirname(os.getcwd())) / ssh_name
gen_key(ssh_path)
# Out:
# /content
# ERROR: Could not find a version that satisfies the requirement torch==2.0.0+cu118 (from versions: 2.2.0, 2.2.0+cu118, 2.2.1, 2.2.1+cu118, 2.2.2, 2.2.2+cu118, 2.3.0, 2.3.0+cu118, 2.3.1, 2.3.1+cu118, 2.4.0, 2.4.0+cu118, 2.4.1, 2.4.1+cu118, 2.5.0, 2.5.0+cu118, 2.5.1, 2.5.1+cu118, 2.6.0, 2.6.0+cu118, 2.7.0, 2.7.0+cu118, 2.7.1, 2.7.1+cu118, 2.8.0, 2.9.0, 2.9.1)
# ERROR: No matching distribution found for torch==2.0.0+cu118
# ...

# %%
# !pip install torch==2.2.0

# %%
# !pip install torch==2.2.0 torchvision==0.17.0 torchaudio==2.2.0 --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 65.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 126.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.24.0+cu126
#     Uninstalling torchvision-0.24.0+cu126:
#       Successfully uninstalled torchvision-0.24.0+cu126
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.9.0+cu126
#     Uninstalling torchaudio-2.9.0+cu126:
#       Successfully uninstalled torchaudio-2.9.0+cu126
# ...

# %%
# !pip install -q xformers triton -U
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.9/122.9 MB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.7/899.7 MB 1.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.5/170.5 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 3.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 104.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 68.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 1.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 70.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 12.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 5.3 MB/s eta 0:00:00
# ...

# %%
# %cd /content/Grounded-Segment-Anything

import threading
def tunnel():
  # !ssh -R 80:127.0.0.1:7860 -o StrictHostKeyChecking=no -i /content/Grounded-Segment-Anything/id_rsa remote.moe
threading.Thread(target=tunnel, daemon=True).start()

print("Please wait until you see the 'Running on local URL' message.")

# !python gradio_app.py --debug --share
# Out:
# /content/Grounded-Segment-Anything
# Please wait until you see the 'Running on local URL' message.
# ...
# Hello!
# remote.moe (the service) is closed down until a viable authentication scheme is implemented
#
# https://github.com/fasmide/remotemoe/discussions/14
# Connection to remote.moe closed by remote host.
# Connection to remote.moe closed.
# Traceback (most recent call last):
#   File "/content/Grounded-Segment-Anything/gradio_app.py", line 12, in <module>
#     import GroundingDINO.groundingdino.datasets.transforms as T
#   File "/content/Grounded-Segment-Anything/GroundingDINO/groundingdino/datasets/transforms.py", line 13, in <module>
#     from groundingdino.util.box_ops import box_xyxy_to_cxcywh
# ModuleNotFoundError: No module named 'groundingdino'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
# !lsb_release -a
# Out:
# No LSB modules are available.
# Distributor ID:	Ubuntu
# Description:	Ubuntu 22.04.4 LTS
# Release:	22.04
# Codename:	jammy

# %%
# !cat /etc/os-release
# Out:
# PRETTY_NAME="Ubuntu 22.04.4 LTS"
# NAME="Ubuntu"
# VERSION_ID="22.04"
# VERSION="22.04.4 LTS (Jammy Jellyfish)"
# VERSION_CODENAME=jammy
# ID=ubuntu
# ID_LIKE=debian
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# UBUNTU_CODENAME=jammy

# %%
# !uname -r
# Out:
# 6.6.105+

# %%
import torch
print(torch.__version__)
# Out:
# 2.9.1+cu128

# %%
python3 -c "import cv2; print('OpenCV:', cv2.__version__)"
# Out:
#   File "/tmp/ipython-input-3514453598.py", line 1
#     python3 -c "import cv2; print('OpenCV:', cv2.__version__)"
#                ^
# SyntaxError: invalid syntax

# %%
python3 -c "import numpy; print('NumPy:', numpy.__version__)"
# Out:
#   File "/tmp/ipython-input-4157650414.py", line 1
#     python3 -c "import numpy; print('NumPy:', numpy.__version__)"
#                ^
# SyntaxError: invalid syntax

# %%
python -c "import numpy; print('NumPy:', numpy.__version__)"
# Out:
#   File "/tmp/ipython-input-391494116.py", line 1
#     python -c "import numpy; print('NumPy:', numpy.__version__)"
#               ^
# SyntaxError: invalid syntax

# %%
python --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1576056767.py in <cell line: 0>()
# ----> 1 python --version
#
# NameError: name 'python' is not defined

# %%
# !python --version
# Out:
# Python 3.12.12

# %%
# Colab面试环境一键检查脚本
print("="*60)
print("面试环境快速检查")
print("="*60)

# 1. 系统与驱动
print("\n1. 系统与GPU信息：")
# !cat /etc/os-release | grep PRETTY_NAME
# !nvidia-smi --query-gpu=name,driver_version --format=csv,noheader

# 2. Python环境
print("\n2. Python与关键包版本：")
import sys, platform
print(f"Python: {sys.version.split()[0]}")
print(f"系统: {platform.platform()}")

# 3. 深度学习框架
print("\n3. 深度学习框架：")
# PyTorch
import torch
tf_available = torch.cuda.is_available()
print(f"PyTorch: {torch.__version__}, CUDA可用: {tf_available}", end="")
if tf_available:
    print(f", CUDA版本: {torch.version.cuda}, GPU: {torch.cuda.get_device_name(0)}")
else:
    print("")
# TensorFlow
import tensorflow as tf
print(f"TensorFlow: {tf.__version__}, GPU可见: {len(tf.config.list_physical_devices('GPU'))>0}")
# Transformers (因其在AI研究中极其重要)
try:
    import transformers
    print(f"Transformers: {transformers.__version__}")
except ImportError:
    print("Transformers: 未安装")

# 4. 数据处理库
print("\n4. 数据处理与视觉库：")
import numpy, pandas, PIL
print(f"NumPy: {numpy.__version__}, Pandas: {pandas.__version__}, Pillow: {PIL.__version__}")
try:
    import cv2
    print(f"OpenCV: {cv2.__version__}")
except ImportError:
    print("OpenCV: 未安装")

print("="*60)
print("环境检查完成。")
print("="*60)
# Out:
# ...
# 面试环境快速检查
# ...
#
# 1. 系统与GPU信息：
# PRETTY_NAME="Ubuntu 22.04.4 LTS"
# Tesla T4, 550.54.15
#
# 2. Python与关键包版本：
# Python: 3.12.12
# 系统: Linux-6.6.105+-x86_64-with-glibc2.35
#
# 3. 深度学习框架：
# PyTorch: 2.9.1+cu128, CUDA可用: True, CUDA版本: 12.8, GPU: Tesla T4
# TensorFlow: 2.19.0, GPU可见: True
# Transformers: 4.57.3
#
# 4. 数据处理与视觉库：
# NumPy: 2.0.2, Pandas: 2.2.2, Pillow: 11.3.0
# OpenCV: 4.12.0
# ...
# 环境检查完成。
# ...
